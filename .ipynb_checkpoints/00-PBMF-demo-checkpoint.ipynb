# %%
# !git clone https://github.com/gaarangoa/samecode.git
# Out:
# fatal: destination path 'samecode' already exists and is not an empty directory.

# %%
import sys

# %%
# sys.path.append('./samecode')

import pandas as pd
import numpy as np
import seaborn as sns

# %config InlineBackend.figure_format = 'svg'

# %%
from samecode.plot.pyplot import subplots
from samecode.survival.plot import KMPlot
from samecode.random import set_seed
from samecode.logger.mlflow import Logger
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-94e2c5006f54> in <module>
# ----> 1 from samecode.plot.pyplot import subplots
#       2 from samecode.survival.plot import KMPlot
#       3 from samecode.random import set_seed
#       4 from samecode.logger.mlflow import Logger
#
# ModuleNotFoundError: No module named 'samecode.plot'

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# %%
# KMPlot.plot?
linewidth=2

t1 = 'IO'
ct = 'SOC'
KMARGS = dict(
    x_legend = 0.5, y_legend = 0.95, legend_font_size=8,
    comparisons=[
        ['{}_B+'.format(t1), '{}_B+'.format(ct), 'B+: '.format()],
        ['{}_B-'.format(t1), '{}_B-'.format(ct), 'B-: '.format()],
        ['{}_B+'.format(t1), '{}_B-'.format(t1), 'IO: '.format()],
        ['{}_B+'.format(ct), '{}_B-'.format(ct), 'SOC: '.format()]
    ],
    x_hr_legend = 0.0, y_hr_legend = 0.2, hr_font_size=8, 
    hr_color='black',
    linewidth=linewidth,
    template_color = '#8A8F91',
    linestyle=['--', '-', '--', '-'],
    show_censor=True
)

# %% [markdown]
# # Poplar to OAK

# %% [markdown]
# ## Dataset

# %%
dataset = pd.read_csv('./ML-ready-oak-poplar.tsv', sep='\t')

# %%
dataset['HIST'] = dataset['HIST'].replace(['NON-SQUAMOUS', 'SQUAMOUS'], [0, 1])
dataset['SEX'] = dataset['SEX'].replace(['F', 'M'], [0, 1])
dataset['TOBHX'] = dataset['TOBHX'].replace(['NEVER', 'PREVIOUS', 'CURRENT'], [0, 0.5, 1])

# %%
dataset = dataset[dataset.QC_Status == 'pass'].reset_index()

# %%
dataset['treat'] = dataset.Treatment.replace(['SOC', 'IO'], [0, 1])
dataset['OS_EVENT'] = 1 - dataset['OS.CNSR']
dataset['PFS_EVENT'] = 1 - dataset['PFS.CNSR']

# %%
mutations = list(dataset.columns[dataset.columns.str.match('mutations_')])

# %%
Counter(dataset.Treatment)
# Out:
# Counter({'SOC': 421, 'IO': 423})

# %%
data_train, data_test = dataset[dataset.Study_x == 'POPLAR'],  dataset[dataset.Study_x == 'OAK']
data_train = data_train.reset_index(drop=True).copy()
data_test = data_test.reset_index(drop=True).copy()

data_train.shape, data_test.shape
# Out:
# ((206, 843), (638, 843))

# %%
top_genes = list(data_train[mutations].sum().sort_values(ascending=False)[:20].keys())

# %% [markdown]
# ## Parameters

# %%
time = 'OS'
event = 'OS_EVENT'
treatment = 'treat'

features = [  
    # Molecular derived features
    'blSLD',
    'btmb',
    'MSAF', 
    
    # Tumor characteristics
    'METSITES',
    'HIST',
    'ECOGGR',
    
    # Patient characteristics
    'SEX',
    'BAGE',
    'TOBHX',
]

top_genes = list(data_train[mutations].sum().sort_values(ascending=False)[:20].keys())

# %% [markdown]
# ## PBMF Modeling

# %%
from PBMF.attention.model_zoo.SimpleModel import Net
from PBMF.attention.model_zoo.Ensemble import EnsemblePBMF

# %%
seed = 0
params = dict(
    ignore_patients_frac=0.1, # During training, ignore this % of patients before computing the loss
    layers=[64],
    epochs=500,
    minp=0.75, # force the model to get this minimum population
    w1=1.0, 
    w2=0.0,
    seed=0,
    embeddings_dim=32,
    learning_rate=0.01,
    shuffle=True,
    shuffle_features=False,
    l1=0.0,
)

# %%
pbmf = EnsemblePBMF(
    time=time, 
    event=event,
    treatment=treatment,
    stratify=treatment,
    features = features + top_genes,
    discard_n_features=1,
    architecture=Net, 
    **params
)

pbmf.fit(
    data_train, 
    num_models=1, 
    n_jobs=1,
    test_size=0.2, 
    outdir='./runs/emsemble_simple_model/',
    save_freq=100,
)
# Out:
# 2023-11-02 15:54:20,385 - PBMF - INFO - ./runs/emsemble_simple_model_3//0//parameters.yaml
# 2023-11-02 15:54:20,385 - PBMF - INFO - ./runs/emsemble_simple_model_3//0//parameters.yaml

# %% [markdown]
# ## Model Performance

# %%
pbmf = EnsemblePBMF()
pbmf.load(
    architecture=Net,
    outdir='./runs/emsemble_simple_model/',
    num_models=100,
)

# %%
data_train['consensus_risk'] = pbmf.predict(data_train, epoch=500)
data_test['consensus_risk'] = pbmf.predict(data_test, epoch=500) #parallel_predict
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# OSErrorTraceback (most recent call last)
# <ipython-input-21-8fee59a31137> in <module>
# ----> 1 data_train['consensus_risk'] = pbmf.predict(data_train, epoch=500)
#       2 data_test['consensus_risk'] = pbmf.predict(data_test, epoch=500) #parallel_predict
#
# ~/proj/PODS/GeMinAI/PLF/PBMF/attention/model_zoo/Ensemble.py in predict(self, data, epoch, **kwargs)
#     153         for seed in tqdm(iterator, total=len(iterator)):
#     154             model = PBMF(architecture=architecture)
# --> 155             model.load_model("{}/{}/".format(outdir, seed), model='cp-{epoch:09d}.h5'.format(epoch=epoch))
#     156             risk = model.predict(data)[0][:, int(model.bix)]
#     157             if return_all_models_predictions:
#
# ~/proj/PODS/GeMinAI/PLF/PBMF/attention/__init__.py in load_model(self, artifacts, model, **kwargs)
#     181
#     182         self.model.predict(self.model.__dummy_data__);
# --> 183         self.model.load_weights('{}/{}'.format(self.artifacts, model))
#     184         self.bix = self.get_biomarker_index(epoch=int(model.replace('cp-', '').replace('.h5', '')))
#     185
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py in load_weights(self, filepath, by_name, skip_mismatch, options)
#    2352             'first, then load the weights.')
#    2353       self._assert_weights_created()
# -> 2354       with h5py.File(filepath, 'r') as f:
#    2355         if 'layer_names' not in f.attrs and 'model_weights' in f:
#    2356           f = f['model_weights']
#
# /usr/local/lib/python3.6/dist-packages/h5py/_hl/files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, **kwds)
#     425                                fapl, fcpl=make_fcpl(track_order=track_order, fs_strategy=fs_strategy,
#     426                                fs_persist=fs_persist, fs_threshold=fs_threshold),
# --> 427                                swmr=swmr)
#     428
#     429             if isinstance(libver, tuple):
#
# /usr/local/lib/python3.6/dist-packages/h5py/_hl/files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     188         if swmr and swmr_support:
#     189             flags |= h5f.ACC_SWMR_READ
# --> 190         fid = h5f.open(name, flags, fapl=fapl)
#     191     elif mode == 'r+':
#     192         fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5f.pyx in h5py.h5f.open()
#
# OSError: Unable to open file (unable to open file: name = './runs/emsemble_simple_model_2//0//cp-000000500.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)

# %%
B = ['B-', 'B+']

thr = 0.5

data_train['bin_risk'] = (data_train['consensus_risk'] > thr).replace([False, True], B)
data_test['bin_risk'] = (data_test['consensus_risk'] > thr).replace([False, True], B)

# %%
f, axs = subplots(cols=2, rows=1, w=10, h=3, return_f=True)

KMPlot(data_train, time=time, event=event, label=['Treatment', 'bin_risk']).plot(
    ax=axs[0],
    title='(POPLAR - Train)',
    **KMARGS
);


KMPlot(data_test, time=time, event=event, label=['Treatment', 'bin_risk']).plot(
    ax=axs[1],
    title='(OAK - Validation)',
    **KMARGS
);

sns.despine(offset=10);

# %%
# data_train.to_csv('./train_predicted_scores.csv', index=False)
# data_test.to_csv('./test_predicted_scores.csv', index=False)

# %% [markdown]
# # Inspect results

# %%
import yaml
outdir='./runs/emsemble_simple_model/'

metrics = []
features = []
for i in range(100):
    m = pd.read_csv('{}/{}/metrics.csv'.format(outdir, i))
    m['seed'] = i
    
    f = yaml.load(open('{}/{}/parameters.yaml'.format(outdir, i)), Loader=yaml.SafeLoader)
    f = f['dataloader_params']['features']
    features.append({'seed': i, 'features': f})
    
    metrics.append(m)
    
metrics = pd.concat(metrics)
metrics['epoch'] = metrics.index

metrics.reset_index(drop=True, inplace=True)

metrics['ratio_d'] = metrics['logrank_hazard_ratio_treatment'] / metrics['logrank_hazard_ratio_control']
metrics['ratio_i'] = metrics['logrank_hazard_ratio_control'] / metrics['logrank_hazard_ratio_treatment']

metrics['ratio'] = metrics[['ratio_d', 'ratio_i']].min(axis=1)

# %%
# sns.kdeplot(metrics[metrics.epoch == 499].ratio)

# %%
# sns.lineplot(data=metrics[metrics.seed.isin([0, 1, 3, 4, 5, 6, 7, 8, 9, 10])], x='epoch', y='ratio')

# %%
features = [  
    # Molecular derived features
    'blSLD',
    'btmb',
    'MSAF', 
    
    # Tumor characteristics
    'METSITES',
    'HIST',
    'ECOGGR',
    
    # Patient characteristics
    'SEX',
    'BAGE',
    'TOBHX',
]

# %%
features + top_genes
# Out:
# ['blSLD',
#  'btmb',
#  'MSAF',
#  'METSITES',
#  'HIST',
#  'ECOGGR',
#  'SEX',
#  'BAGE',
#  'TOBHX',
#  'mutations_TP53',
#  'mutations_LRP1B',
#  'mutations_DNMT3A',
#  'mutations_SPTA1',
#  'mutations_NF1',
#  'mutations_FAT3',
#  'mutations_KEAP1',
#  'mutations_STAG2',
#  'mutations_MLL2',
#  'mutations_MLL3',
#  'mutations_ATM',
#  'mutations_TSC1',
#  'mutations_FAT1',
#  'mutations_EGFR',
#  'mutations_STK11',
#  'mutations_NFE2L2',
#  'mutations_PREX2',
#  'mutations_EPHA3',
#  'mutations_CHEK2',
#  'mutations_PDGFRA']
